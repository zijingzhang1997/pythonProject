# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np
import scipy
import matplotlib.image as mpimg
from scipy.interpolate import griddata
from scipy.optimize import minimize

path='F:\lecture document\ECE 4250 signal\project'
#import training, validation
imgsource_t01 = nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_01\images\analyze\IBSR_01_ana.img')
img_t01=imgsource_t01.get_data()
img_t01=img_t01[:,:,64,0]  
imgsource_t01_seg= nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_01\segmentation\analyze\IBSR_01_seg_ana.img')
img_t01_seg=imgsource_t01_seg.get_data()
img_t01_seg=img_t01_seg[:,:,64,0]

imgsource_t02 = nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_02\images\analyze\IBSR_02_ana.img')
img_t02=imgsource_t02.get_data()
img_t02=img_t02[:,:,64,0]  
imgsource_t02_seg= nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_02\segmentation\analyze\IBSR_02_seg_ana.img')
img_t02_seg=imgsource_t02_seg.get_data()
img_t02_seg=img_t02_seg[:,:,64,0]

imgsource_t03 = nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_03\images\analyze\IBSR_03_ana.img')
img_t03=imgsource_t03.get_data()
img_t03=img_t03[:,:,64,0]  
imgsource_t03_seg= nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_03\segmentation\analyze\IBSR_03_seg_ana.img')
img_t03_seg=imgsource_t03_seg.get_data()
img_t03_seg=img_t03_seg[:,:,64,0]

imgsource_t04 = nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_04\images\analyze\IBSR_04_ana.img')
img_t04=imgsource_t04.get_data()
img_t04=img_t04[:,:,64,0]  
imgsource_t04_seg= nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_04\segmentation\analyze\IBSR_04_seg_ana.img')
img_t04_seg=imgsource_t04_seg.get_data()
img_t04_seg=img_t04_seg[:,:,64,0]

imgsource_t05 = nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_05\images\analyze\IBSR_05_ana.img')
img_t05=imgsource_t05.get_data()
img_t05=img_t05[:,:,64,0]  
imgsource_t05_seg= nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_05\segmentation\analyze\IBSR_05_seg_ana.img')
img_t05_seg=imgsource_t05_seg.get_data()
img_t05_seg=img_t05_seg[:,:,64,0]

imgsource_t06 = nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_06\images\analyze\IBSR_06_ana.img')
img_t06=imgsource_t06.get_data()
img_t06=img_t06[:,:,64,0]  
imgsource_t06_seg= nib.load(r'F:\lecture document\ECE 4250 signal\project\Training\IBSR_06\segmentation\analyze\IBSR_06_seg_ana.img')
img_t06_seg=imgsource_t06_seg.get_data()
img_t06_seg=img_t06_seg[:,:,64,0]


# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_01_ana.png',img_t01)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_01_seg_ana.png',img_t01_seg)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_02_ana.png',img_t02)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_02_seg_ana.png',img_t02_seg)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_03_ana.png',img_t03)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_03_seg_ana.png',img_t03_seg)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_04_ana.png',img_t04)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_04_seg_ana.png',img_t04_seg)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_05_ana.png',img_t05)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_05_seg_ana.png',img_t05_seg)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_06_ana.png',img_t06)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\training_fig\IBSR_06_seg_ana.png',img_t06_seg)


imgsource_v07 = nib.load(r'F:\lecture document\ECE 4250 signal\project\Validation\IBSR_07\images\analyze\IBSR_07_ana.img')
img_v07=imgsource_v07.get_data()
img_v07=img_v07[:,:,64,0]  
imgsource_v07_seg= nib.load(r'F:\lecture document\ECE 4250 signal\project\Validation\IBSR_07\segmentation\analyze\IBSR_07_seg_ana.img')
img_v07_seg=imgsource_v07_seg.get_data()
img_v07_seg=img_v07_seg[:,:,64,0]
imgsource_v15 = nib.load(r'F:\lecture document\ECE 4250 signal\project\Validation\IBSR_15\images\analyze\IBSR_15_ana.img')
img_v15=imgsource_v15.get_data()
img_v15=img_v15[:,:,64,0]  
imgsource_v15_seg= nib.load(r'F:\lecture document\ECE 4250 signal\project\Validation\IBSR_15\segmentation\analyze\IBSR_15_seg_ana.img')
img_v15_seg=imgsource_v15_seg.get_data()
img_v15_seg=img_v15_seg[:,:,64,0]

# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\validation_fig\IBSR_07_ana.png',img_v07)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\validation_fig\IBSR_07_seg_ana.png',img_v07_seg)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\validation_fig\IBSR_15_ana.png',img_v15)
# mpimg.imsave(r'F:\lecture document\ECE 4250 signal\project\validation_fig\IBSR_15_seg_ana.png',img_v15_seg)
def normalize(img):
    max=np.amax(img)
    min=np.amin(img)
    img=(img-min)/(max-min)
    return img

img_t01=normalize(img_t01)
img_t02=normalize(img_t02)
img_t03=normalize(img_t03)
img_t04=normalize(img_t04)
img_t05=normalize(img_t05)
img_t06=normalize(img_t06)
img_v07=normalize(img_v07)
img_v15=normalize(img_v15)
# Out:
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   if sys.path[0] == '':
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   from ipykernel import kernelapp as app
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:72: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:75: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# C:\Users\zzj\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0

# %%
#1.1 
T0=np.array([1,1,0,0,0])#T=np.array([sx, thetax,sy,thetay, tx,ty])



def transform(img_m,T,img_f_size):
    xmax=img_m.shape[0]
    ymax=img_m.shape[1]

    x0=np.linspace(-(xmax/2) +1,xmax/2,xmax)   #x,y[-127,128]
    y0=np.linspace(-(ymax/2) +1,ymax/2,ymax)
    x,y=np.meshgrid(x0,y0)
    x_t=np.zeros([xmax,ymax])
    y_t=np.zeros([xmax,ymax])
    
    Trans=([T[0]*np.cos(T[2]),-T[0]*np.sin(T[2]),T[3]],[T[1]*np.sin(T[2]),T[1]*np.cos(T[2]),T[4]],[0,0,1])
    for i in range(xmax):
        for j in range(ymax):
          
            index=np.array([x[i,j],y[i,j],1])
            T_index=np.dot(Trans,index)
            T_index=np.array(T_index)
            x_t[i,j]=T_index[0]
            y_t[i,j]=T_index[1]
   
    
    x0f=np.linspace(-(img_f_size[0]/2)+1,img_f_size[0]/2,img_f_size[0])  #x,y[-127,128]
    y0f=np.linspace(-(img_f_size[1]/2)+1,img_f_size[1]/2,img_f_size[1])
    xf,yf=np.meshgrid(x0f,y0f)
    
    img_moved = griddata((x_t.flatten(),y_t.flatten()), img_m.flatten(), (xf, yf), method='linear',fill_value=0)#resample

    return img_moved

#1.2
def lossFunction(T,img_m,img_f):
    img_moved=transform(img_m,T,img_f.shape)
    #L=np.sum(math.pow(img_f[:,:] -img_moved[:,:],2))
    L=0
    for i in range(img_f.shape[0]):
        for j in range(img_f.shape[1]):
            L+=(img_f[i,j] -img_moved[i,j])**2

    return L


#2
# res_t01v07 = minimize(lossFunction, T0,args=(img_t01,img_v07),method='Powell',options={'maxiter': 50})
# #res1 = minimize(lossFunction, T,args=(img1,img3),method='Nelder-Mead',options={'maxiter': 100})
# print(res_t01v07)
# Topt_t01v07=res_t01v07.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t01v07.npy',Topt_t01v07)
# img_moved_t01v07=transform(img_t01,Topt_t01v07,img_v07.shape)
# fig = plt.figure()
# plt.imshow(img_t01)
# plt.title('training01')
# fig = plt.figure()
# plt.imshow(img_v07) 
# plt.title('validation07')
# fig = plt.figure()
# plt.imshow(img_moved_t01v07)
# plt.title('training01 moved ')


# res_t02v07 = minimize(lossFunction, T0,args=(img_t02,img_v07),method='Powell',options={'maxiter': 50})
# Topt_t02v07=res_t02v07.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t02v07.npy',Topt_t02v07)
# res_t03v07 = minimize(lossFunction, T0,args=(img_t03,img_v07),method='Powell',options={'maxiter': 50})
# Topt_t03v07=res_t03v07.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t03v07.npy',Topt_t03v07)
# res_t04v07 = minimize(lossFunction, T0,args=(img_t04,img_v07),method='Powell',options={'maxiter': 50})
# Topt_t04v07=res_t04v07.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t04v07.npy',Topt_t04v07)
# res_t05v07 = minimize(lossFunction, T0,args=(img_t05,img_v07),method='Powell',options={'maxiter': 50})
# Topt_t05v07=res_t05v07.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t05v07.npy',Topt_t05v07)
# res_t06v07 = minimize(lossFunction, T0,args=(img_t06,img_v07),method='Powell',options={'maxiter': 50})
# Topt_t06v07=res_t06v07.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t06v07.npy',Topt_t06v07)

# res_t01v15 = minimize(lossFunction, T0,args=(img_t01,img_v15),method='Powell',options={'maxiter': 50})
# Topt_t01v15=res_t01v15.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t01v15.npy',Topt_t01v15)
# res_t02v15 = minimize(lossFunction, T0,args=(img_t02,img_v15),method='Powell',options={'maxiter': 50})
# Topt_t02v15=res_t02v15.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t02v15.npy',Topt_t02v15)
# res_t03v15 = minimize(lossFunction, T0,args=(img_t03,img_v15),method='Powell',options={'maxiter': 50})
# Topt_t03v15=res_t03v15.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t03v15.npy',Topt_t03v15)
# res_t04v15 = minimize(lossFunction, T0,args=(img_t04,img_v15),method='Powell',options={'maxiter': 50})
# Topt_t04v15=res_t04v15.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t04v15.npy',Topt_t04v15)
# res_t05v15 = minimize(lossFunction, T0,args=(img_t05,img_v15),method='Powell',options={'maxiter': 50})
# Topt_t05v15=res_t05v15.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t05v15.npy',Topt_t05v15)
# res_t06v15 = minimize(lossFunction, T0,args=(img_t06,img_v15),method='Powell',options={'maxiter': 50})
# Topt_t06v15=res_t06v15.x
# np.save('F:\lecture document\ECE 4250 signal\project\Topt2\Topt_t06v15.npy',Topt_t06v15)

# %%
#load T opt 
Topt_t01v07=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t01v07.npy')
Topt_t02v07=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t02v07.npy')
Topt_t03v07=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t03v07.npy')
Topt_t04v07=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t04v07.npy')
Topt_t05v07=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t05v07.npy')
Topt_t06v07=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t06v07.npy')

Topt_t01v15=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t01v15.npy')
Topt_t02v15=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t02v15.npy')
Topt_t03v15=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t03v15.npy')
Topt_t04v15=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t04v15.npy')
Topt_t05v15=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t05v15.npy')
Topt_t06v15=np.load('F:\lecture document\ECE 4250 signal\project\Topt3\Topt_t06v15.npy')
print(Topt_t01v07)
print(Topt_t02v07)
print(Topt_t03v07)
print(Topt_t04v07)
print(Topt_t05v07)
print(Topt_t06v07)
print(Topt_t01v15)
print(Topt_t02v15)
print(Topt_t03v15)
print(Topt_t04v15)
print(Topt_t05v15)
print(Topt_t06v15)

img_moved_t01v07=transform(img_t01,Topt_t01v07,img_v07.shape)
img_moved_t02v07=transform(img_t02,Topt_t02v07,img_v07.shape)
img_moved_t03v07=transform(img_t03,Topt_t03v07,img_v07.shape)
img_moved_t04v07=transform(img_t04,Topt_t04v07,img_v07.shape)
img_moved_t05v07=transform(img_t05,Topt_t05v07,img_v07.shape)
img_moved_t06v07=transform(img_t06,Topt_t06v07,img_v07.shape)

img_moved_t01v15=transform(img_t01,Topt_t01v15,img_v15.shape)
img_moved_t02v15=transform(img_t02,Topt_t02v15,img_v15.shape)
img_moved_t03v15=transform(img_t03,Topt_t03v15,img_v15.shape)
img_moved_t04v15=transform(img_t04,Topt_t04v15,img_v15.shape)
img_moved_t05v15=transform(img_t05,Topt_t05v15,img_v15.shape)
img_moved_t06v15=transform(img_t06,Topt_t06v15,img_v15.shape)
# Out:
# [ 9.42599818e-01  9.06425433e-01 -1.99105451e-04  3.02277835e+00
#   2.82775952e-01]
# [ 8.78243131e-01  8.86061619e-01 -9.77208174e-04  4.10732991e+00
#   2.10430553e-01]
# [1.02583353e+00 9.26740006e-01 5.24315114e-04 6.38641399e+00
#  1.52165685e-01]
# [ 1.02830466e+00  9.40775564e-01 -6.16571121e-04  5.20197497e+00
#   1.32648099e-02]
# [ 9.45590741e-01  9.38469547e-01 -2.42492429e-04  5.48212347e+00
#   5.46278331e-01]
# [9.60719102e-01 9.37511341e-01 4.56065607e-03 8.46632367e+00
#  3.75086724e-02]
# [ 9.65916966e-01  1.06104895e+00 -1.68238737e-10 -3.99694394e+00
#   9.28986295e-01]
# [ 9.38298581e-01  1.02175055e+00  5.45338393e-10 -2.84254102e+00
#   5.69965280e-02]
# [ 1.17666660e+00  9.79577848e-01 -2.61543228e-10  4.62694563e+00
#   3.19004253e-02]
# [1.1909023  1.04822966 0.00336083 2.65791075 1.05699296]
# [ 9.66329764e-01  1.07523255e+00 -3.14342170e-10 -3.17308254e+00
#   3.84296424e-03]
# [1.02221722 1.07866405 0.00135769 0.21293283 0.07156588]

# %%
#3

def transform_seg(img_m,T,img_f_size):
    xmax=img_m.shape[0]
    ymax=img_m.shape[1]

    x0=np.linspace(-(xmax/2) +1,xmax/2,xmax)   #x,y[-127,128]
    y0=np.linspace(-(ymax/2) +1,ymax/2,ymax)
    x,y=np.meshgrid(x0,y0)
    x_t=np.zeros([xmax,ymax])
    y_t=np.zeros([xmax,ymax])
    
    Trans=([T[0]*np.cos(T[2]),-T[0]*np.sin(T[2]),T[3]],[T[1]*np.sin(T[2]),T[1]*np.cos(T[2]),T[4]],[0,0,1])
    for i in range(xmax):
        for j in range(ymax):
          
            index=np.array([x[i,j],y[i,j],1])
            T_index=np.dot(Trans,index)
            T_index=np.array(T_index)
            x_t[i,j]=T_index[0]
            y_t[i,j]=T_index[1]
   
    
    x0f=np.linspace(-(img_f_size[0]/2)+1,img_f_size[0]/2,img_f_size[0])  #x,y[-127,128]
    y0f=np.linspace(-(img_f_size[1]/2)+1,img_f_size[1]/2,img_f_size[1])
    xf,yf=np.meshgrid(x0f,y0f)
    
    img_moved = griddata((x_t.flatten(),y_t.flatten()), img_m.flatten(), (xf, yf), method='nearest',fill_value=0)#resample

    return img_moved

img_moved_t01v07_seg=transform_seg(img_t01_seg,Topt_t01v07,img_v07_seg.shape)
img_moved_t02v07_seg=transform_seg(img_t02_seg,Topt_t02v07,img_v07_seg.shape)
img_moved_t03v07_seg=transform_seg(img_t03_seg,Topt_t03v07,img_v07_seg.shape)
img_moved_t04v07_seg=transform_seg(img_t04_seg,Topt_t04v07,img_v07_seg.shape)
img_moved_t05v07_seg=transform_seg(img_t05_seg,Topt_t05v07,img_v07_seg.shape)
img_moved_t06v07_seg=transform_seg(img_t06_seg,Topt_t06v07,img_v07_seg.shape)

img_moved_t01v15_seg=transform_seg(img_t01_seg,Topt_t01v15,img_v15_seg.shape)
img_moved_t02v15_seg=transform_seg(img_t02_seg,Topt_t02v15,img_v15_seg.shape)
img_moved_t03v15_seg=transform_seg(img_t03_seg,Topt_t03v15,img_v15_seg.shape)
img_moved_t04v15_seg=transform_seg(img_t04_seg,Topt_t04v15,img_v15_seg.shape)
img_moved_t05v15_seg=transform_seg(img_t05_seg,Topt_t05v15,img_v15_seg.shape)
img_moved_t06v15_seg=transform_seg(img_t06_seg,Topt_t06v15,img_v15_seg.shape)

# %%
#4 compute most frequent training label
from collections import Counter

def fusion(img_v_seg,img_moved_t01v_seg,img_moved_t02v_seg,img_moved_t03v_seg,
           img_moved_t04v_seg,img_moved_t05v_seg,img_moved_t06v_seg):
    img_v_autoseg=np.zeros([img_v_seg.shape[0],img_v_seg.shape[1]])
    for i in range (img_v_seg.shape[0]):
        for j in range (img_v_seg.shape[1]):
            result=[]
            result.append(img_moved_t01v_seg[i,j])
            result.append(img_moved_t02v_seg[i,j])
            result.append(img_moved_t03v_seg[i,j])
            result.append(img_moved_t04v_seg[i,j])
            result.append(img_moved_t05v_seg[i,j])
            result.append(img_moved_t06v_seg[i,j])
            result_counts = Counter(result)
            top = result_counts.most_common(1)
            img_v_autoseg[i,j]=top[0][0]
    return img_v_autoseg

img_v07_autoseg=fusion(img_v07_seg,img_moved_t01v07_seg,img_moved_t02v07_seg,img_moved_t03v07_seg,
img_moved_t04v07_seg,img_moved_t05v07_seg,img_moved_t06v07_seg)
img_v15_autoseg=fusion(img_v15_seg,img_moved_t01v15_seg,img_moved_t02v15_seg,img_moved_t03v15_seg,
img_moved_t04v15_seg,img_moved_t05v15_seg,img_moved_t06v15_seg)        

        
fig = plt.figure()
plt.imshow(img_v07_autoseg)
fig = plt.figure()
plt.imshow(img_v15_autoseg)

fig = plt.figure()
plt.imshow(img_t01_seg)
plt.title('training01')
fig = plt.figure()
plt.imshow(img_v15_seg) 
plt.title('validation15')
fig = plt.figure()
plt.imshow(img_moved_t01v15_seg)
plt.title('training01 moved ')
# Out:
# Text(0.5, 1.0, 'training01 moved ')

# %%
#4 compute most frequent training label
# def fusion2(img_v_seg,img_t01v_seg,img_t02v_seg,img_t03v_seg,
#            img_t04v_seg,img_t05v_seg,img_t06v_seg):
#     img_v_autoseg=np.zeros([img_v_seg.shape[0],img_v_seg.shape[1]])
#     img1_6=np.array([img_t01v_seg,img_t02v_seg,img_t03v_seg,
#            img_t04v_seg,img_t05v_seg,img_t06v_seg])
#     for i in range (5,img_v_seg.shape[0]-5):
#         for j in range (5,img_v_seg.shape[1]-5):
#             MSE=np.zeros([6,])
#             for m in range(i-1,i+1):
#                 for n in range(j-1,j+1):
#                     MSE[0]+=(img_v_seg[m,n] -img_t01v_seg[m,n])**2
#                     MSE[1]+=(img_v_seg[m,n] -img_t02v_seg[m,n])**2
#                     MSE[2]+=(img_v_seg[m,n] -img_t03v_seg[m,n])**2
#                     MSE[3]+=(img_v_seg[m,n] -img_t04v_seg[m,n])**2
#                     MSE[4]+=(img_v_seg[m,n] -img_t05v_seg[m,n])**2
#                     MSE[5]+=(img_v_seg[m,n] -img_t06v_seg[m,n])**2
#             MSE_min=np.argmin(MSE)
#             img_v_autoseg[i,j]=img1_6[MSE_min,i,j] 
#     return img_v_autoseg
def fusion2(img_v_seg,img_v,img_t01v_seg,img_t02v_seg,img_t03v_seg,
           img_t04v_seg,img_t05v_seg,img_t06v_seg,img_t01v,img_t02v,img_t03v,
           img_t04v,img_t05v,img_t06v):
    img_v_autoseg=np.zeros([img_v_seg.shape[0],img_v_seg.shape[1]])
    img1_6=np.array([img_t01v_seg,img_t02v_seg,img_t03v_seg,
           img_t04v_seg,img_t05v_seg,img_t06v_seg])
    for i in range (5,img_v_seg.shape[0]-5):
        for j in range (5,img_v_seg.shape[1]-5):
            MSE=np.zeros([6,])
            for m in range(i-2,i+2):
                for n in range(j-2,j+2):
                    MSE[0]+=(img_v[m,n] -img_t01v[m,n])**2
                    MSE[1]+=(img_v[m,n] -img_t02v[m,n])**2
                    MSE[2]+=(img_v[m,n] -img_t03v[m,n])**2
                    MSE[3]+=(img_v[m,n] -img_t04v[m,n])**2
                    MSE[4]+=(img_v[m,n] -img_t05v[m,n])**2
                    MSE[5]+=(img_v[m,n] -img_t06v[m,n])**2
            MSE_min=np.argmin(MSE)
            img_v_autoseg[i,j]=img1_6[MSE_min,i,j] 
    return img_v_autoseg
img_v07_autoseg=fusion2(img_v07_seg,img_v07,img_moved_t01v07_seg,img_moved_t02v07_seg,img_moved_t03v07_seg,
img_moved_t04v07_seg,img_moved_t05v07_seg,img_moved_t06v07_seg,img_moved_t01v07,img_moved_t02v07,img_moved_t03v07,
img_moved_t04v07,img_moved_t05v07,img_moved_t06v07)
img_v15_autoseg=fusion2(img_v15_seg,img_v15,img_moved_t01v15_seg,img_moved_t02v15_seg,img_moved_t03v15_seg,
img_moved_t04v15_seg,img_moved_t05v15_seg,img_moved_t06v15_seg,img_moved_t01v15,img_moved_t02v15,img_moved_t03v15,
img_moved_t04v15,img_moved_t05v15,img_moved_t06v15)    

from collections import Counter

def fusion(img_v_seg,img_moved_t01v_seg,img_moved_t02v_seg,img_moved_t03v_seg,
           img_moved_t04v_seg,img_moved_t05v_seg,img_moved_t06v_seg):
    img_v_autoseg=np.zeros([img_v_seg.shape[0],img_v_seg.shape[1]])
    for i in range (img_v_seg.shape[0]):
        for j in range (img_v_seg.shape[1]):
            result=[]
            result.append(img_moved_t01v_seg[i,j])
            result.append(img_moved_t02v_seg[i,j])
            result.append(img_moved_t03v_seg[i,j])
            result.append(img_moved_t04v_seg[i,j])
            result.append(img_moved_t05v_seg[i,j])
            result.append(img_moved_t06v_seg[i,j])
            result_counts = Counter(result)
            top = result_counts.most_common(1)
            img_v_autoseg[i,j]=top[0][0]
    return img_v_autoseg

# img_v07_autoseg=fusion(img_v07_seg,img_moved_t01v07_seg,img_moved_t02v07_seg,img_moved_t03v07_seg,
# img_moved_t04v07_seg,img_moved_t05v07_seg,img_moved_t06v07_seg)
# img_v15_autoseg=fusion(img_v15_seg,img_moved_t01v15_seg,img_moved_t02v15_seg,img_moved_t03v15_seg,
# img_moved_t04v15_seg,img_moved_t05v15_seg,img_moved_t06v15_seg)

# %%
#5 6 Jaccard overlap index
def Jaccard(r,img_auto,img_man): #r =ROI
    inter=[]
    union=[]
    for i in range (img_man.shape[0]):
        for j in range (img_man.shape[1]):
            if img_auto[i,j]==r and img_man[i,j]==r:
                inter.append((i,j))
            if img_auto[i,j]==r or img_man[i,j]==r:
                union.append((i,j))
    ratio=len(inter)/len(union)
    return ratio
J_v07_2=Jaccard(2,img_v07_autoseg,img_v07_seg)
J_v07_3=Jaccard(3,img_v07_autoseg,img_v07_seg)
J_v07_41=Jaccard(41,img_v07_autoseg,img_v07_seg)
J_v07_42=Jaccard(42,img_v07_autoseg,img_v07_seg)

J_v15_2=Jaccard(2,img_v15_autoseg,img_v15_seg)
J_v15_3=Jaccard(3,img_v15_autoseg,img_v15_seg)
J_v15_41=Jaccard(41,img_v15_autoseg,img_v15_seg)
J_v15_42=Jaccard(42,img_v15_autoseg,img_v15_seg)



from tabulate import tabulate
table07 = [["left Cerebral-White-Matter",J_v07_2],["Left Cerebral-Cortex",J_v07_3],["Right Cerebral-White-Matter",J_v07_41],["Right Cerebral-Cortex",J_v07_42]]
print('validation_07:')
print(tabulate(table07))
table15 = [["left Cerebral-White-Matter",J_v15_2],["Left Cerebral-Cortex",J_v15_3],["Right Cerebral-White-Matter",J_v15_41],["Right Cerebral-Cortex",J_v15_42]]
print('validation_15:')
print(tabulate(table15))
# Out:
# validation_07:
# ---------------------------  --------
# left Cerebral-White-Matter   0.533762
# Left Cerebral-Cortex         0.552322
# Right Cerebral-White-Matter  0.538462
# Right Cerebral-Cortex        0.543782
# ---------------------------  --------
# validation_15:
# ---------------------------  --------
# left Cerebral-White-Matter   0.56742
# Left Cerebral-Cortex         0.504342
# Right Cerebral-White-Matter  0.56482
# Right Cerebral-Cortex        0.508217
# ---------------------------  --------

# %%
#5 6 Jaccard overlap index
def Jaccard(r,img_auto,img_man): #r =ROI
    inter=[]
    union=[]
    for i in range (img_man.shape[0]):
        for j in range (img_man.shape[1]):
            if img_auto[i,j]==r and img_man[i,j]==r:
                inter.append((i,j))
            if img_auto[i,j]==r or img_man[i,j]==r:
                union.append((i,j))
    ratio=len(inter)/len(union)
    return ratio
J_v07_2=Jaccard(2,img_v07_autoseg,img_v07_seg)
J_v07_3=Jaccard(3,img_v07_autoseg,img_v07_seg)
J_v07_41=Jaccard(41,img_v07_autoseg,img_v07_seg)
J_v07_42=Jaccard(42,img_v07_autoseg,img_v07_seg)

J_v15_2=Jaccard(2,img_v15_autoseg,img_v15_seg)
J_v15_3=Jaccard(3,img_v15_autoseg,img_v15_seg)
J_v15_41=Jaccard(41,img_v15_autoseg,img_v15_seg)
J_v15_42=Jaccard(42,img_v15_autoseg,img_v15_seg)



from tabulate import tabulate
table07 = [["left Cerebral-White-Matter",J_v07_2],["Left Cerebral-Cortex",J_v07_3],["Right Cerebral-White-Matter",J_v07_41],["Right Cerebral-Cortex",J_v07_42]]
print('validation_07:')
print(tabulate(table07))
table15 = [["left Cerebral-White-Matter",J_v15_2],["Left Cerebral-Cortex",J_v15_3],["Right Cerebral-White-Matter",J_v15_41],["Right Cerebral-Cortex",J_v15_42]]
print('validation_15:')
print(tabulate(table15))
# Out:
# validation_07:
# ---------------------------  --------
# left Cerebral-White-Matter   0.557143
# Left Cerebral-Cortex         0.611327
# Right Cerebral-White-Matter  0.585977
# Right Cerebral-Cortex        0.637919
# ---------------------------  --------
# validation_15:
# ---------------------------  --------
# left Cerebral-White-Matter   0.488901
# Left Cerebral-Cortex         0.363963
# Right Cerebral-White-Matter  0.485624
# Right Cerebral-Cortex        0.39119
# ---------------------------  --------

# %%
fig = plt.figure()
plt.imshow(img_v07_autoseg)
plt.title('validation07 autosegmentation by better transformation 2')
fig = plt.figure()
plt.imshow(img_v15_autoseg)
plt.title('validation15 autosegmentation by better transformation 2')
# Out:
# Text(0.5, 1.0, 'validation15 autosegmentation by better transformation 2')
